# %% [markdown]
# <a href="https://colab.research.google.com/github/angemced/angemced/blob/main/Point_de_contr%C3%B4le_de_pr%C3%A9traitement_des_donn%C3%A9es.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importation des modules numpy et pandas
import pandas as pd
import numpy as np

# %%
#Lecture du fichier steg billing pour debut d'analyse
steg_billing = pd.read_csv('/content/STEG_BILLING_HISTORY.csv', delimiter=',')

# %%
#charger le jeu de donnée
steg_billing
# Out:
#                  client_id invoice_date  tarif_type  counter_number  \
# 0           train_Client_0   2014-03-24        11.0       1335667.0
# 1           train_Client_0   2013-03-29        11.0       1335667.0
# 2           train_Client_0   2015-03-23        11.0       1335667.0
# 3           train_Client_0   2015-07-13        11.0       1335667.0
# 4           train_Client_0   2016-11-17        11.0       1335667.0
# ...                    ...          ...         ...             ...
# 25765  train_Client_100713   2007-05-29        11.0       1077941.0
# 25766  train_Client_100713   2016-11-05        40.0        146251.0
# 25767  train_Client_100713   2007-05-29        40.0        146251.0
# 25768  train_Client_100713   2008-09-24        11.0       1077941.0
# 25769  train_Client_100713   2008-09-24         NaN             NaN
#
#        counter_statue  counter_code  reading_remarque  counter_coefficient  \
# ...

# %%
#affichez les dix premières lignes, stockez les résultats dans une variable appelée 'client_0_bills'.
client_0_bills = steg_billing.head(10)

client_0_bills
# Out:
#         client_id invoice_date  tarif_type  counter_number  counter_statue  \
# 0  train_Client_0   2014-03-24        11.0       1335667.0             0.0
# 1  train_Client_0   2013-03-29        11.0       1335667.0             0.0
# 2  train_Client_0   2015-03-23        11.0       1335667.0             0.0
# 3  train_Client_0   2015-07-13        11.0       1335667.0             0.0
# 4  train_Client_0   2016-11-17        11.0       1335667.0             0.0
# 5  train_Client_0   2017-07-17        11.0       1335667.0             0.0
# 6  train_Client_0   2018-12-07        11.0       1335667.0             0.0
# 7  train_Client_0   2019-03-19        11.0       1335667.0             0.0
# 8  train_Client_0   2011-07-22        11.0       1335667.0             0.0
# 9  train_Client_0   2011-11-22        11.0       1335667.0             0.0
#
#    counter_code  reading_remarque  counter_coefficient  consommation_level_1  \
# ...

# %%
#Quel est le type de données de la variable 'client_0_bills' ?
client_0_bills.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   client_id             10 non-null     object
#  1   invoice_date          10 non-null     object
#  2   tarif_type            10 non-null     float64
#  3   counter_number        10 non-null     float64
#  4   counter_statue        10 non-null     float64
#  5   counter_code          10 non-null     float64
#  6   reading_remarque      10 non-null     float64
#  7   counter_coefficient   10 non-null     float64
#  8   consommation_level_1  10 non-null     float64
#  9   consommation_level_2  10 non-null     float64
#  10  consommation_level_3  10 non-null     float64
#  11  consommation_level_4  10 non-null     float64
#  12  old_index             10 non-null     float64
#  13  new_index             10 non-null     float64
# ...

# %%
#Inspectez le jeu de données à la recherche de valeurs manquantes.
missing_values = steg_billing.isna().sum()
pourcentage = round(steg_billing.isnull().mean()*100, 2)
tableau = pd.concat([missing_values, pourcentage], axis= 1)
tableau.columns = ['ELEMENTS', 'Pourcentage']
tableau
# Out:
#                       ELEMENTS  Pourcentage
# client_id                    0         0.00
# invoice_date                 0         0.00
# tarif_type                   1         0.00
# counter_number               2         0.01
# counter_statue               1         0.00
# counter_code                 1         0.00
# reading_remarque            22         0.09
# counter_coefficient          1         0.00
# consommation_level_1         1         0.00
# consommation_level_2         1         0.00
# consommation_level_3         1         0.00
# consommation_level_4         1         0.00
# old_index                    1         0.00
# new_index                    1         0.00
# months_number                1         0.00
# counter_type                 1         0.00

# %%
#9- Exécutez une analyse descriptive sur les entités numériques (colonnes).
description = steg_billing.describe()
description
# Out:
#          tarif_type  counter_number  counter_statue  counter_code  \
# count  25769.000000    2.576800e+04    25769.000000  25769.000000
# mean      20.057201    9.307823e+10        0.040941    170.910551
# std       13.456173    1.437790e+12        0.360446    131.066614
# min        9.000000    0.000000e+00        0.000000      5.000000
# 25%       11.000000    1.286310e+05        0.000000      5.000000
# 50%       11.000000    4.696800e+05        0.000000    203.000000
# 75%       40.000000    1.136139e+06        0.000000    207.000000
# max       45.000000    2.718114e+13        5.000000    483.000000
#
#        reading_remarque  counter_coefficient  consommation_level_1  \
# count      25748.000000              25769.0          25769.000000
# mean           7.325695                  1.0            414.813574
# std            1.356613                  0.0            514.545718
# min            6.000000                  1.0              0.000000
# ...

# %% [markdown]
# Sélectionnez votre stratégie pour gérer les valeurs manquantes et dites-nous pourquoi vous avez fait ce choix.
# Ma strategie pour gerer les valeurs manquantes c'est d'utiliser la fillna() pour remplacer les valeurs manquantes par 0
# j'ai choisi de mettre 0 car la valeur que je veux changer est reading remarque. Avec le 0 on pourra interpreter qu'il n'y a aucune remaruqe

# %%
#Sélectionnez les enregistrements de factures pour le client avec un id ='train_Client_0', en utilisant 2 méthodes.
#1er méthode
facture_train_client_0= steg_billing.loc[steg_billing['client_id']=='train_Client_0']
#2e methode
facture_trainclient0 =steg_billing.iloc[:35]
# Out:
#         client_id invoice_date  tarif_type  counter_number  counter_statue  \
# 0  train_Client_0   2014-03-24          11       1335667.0               0
# 1  train_Client_0   2013-03-29          11       1335667.0               0
# 2  train_Client_0   2015-03-23          11       1335667.0               0
# 3  train_Client_0   2015-07-13          11       1335667.0               0
# 4  train_Client_0   2016-11-17          11       1335667.0               0
# 5  train_Client_0   2017-07-17          11       1335667.0               0
# 6  train_Client_0   2018-12-07          11       1335667.0               0
# 7  train_Client_0   2019-03-19          11       1335667.0               0
# 8  train_Client_0   2011-07-22          11       1335667.0               0
# 9  train_Client_0   2011-11-22          11       1335667.0               0
#
#    counter_code  reading_remarque  counter_coefficient  consommation_level_1  \
# ...

# %%
#11-Transformez la fonction 'counter_type' en variable numérique à l’aide de l’encodeur de votre choix
infor= steg_billing.info()
steg_billing['counter_type'].values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25770 entries, 0 to 25769
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   client_id             25770 non-null  object
#  1   invoice_date          25770 non-null  object
#  2   tarif_type            25769 non-null  float64
#  3   counter_number        25768 non-null  float64
#  4   counter_statue        25769 non-null  float64
#  5   counter_code          25769 non-null  float64
#  6   reading_remarque      25748 non-null  float64
#  7   counter_coefficient   25769 non-null  float64
#  8   consommation_level_1  25769 non-null  float64
#  9   consommation_level_2  25769 non-null  float64
#  10  consommation_level_3  25769 non-null  float64
#  11  consommation_level_4  25769 non-null  float64
#  12  old_index             25769 non-null  float64
#  13  new_index             25769 non-null  float64
# ...

# %%
#module d_encodage avec LabelEncoder
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
steg_billing['counter_type']= encoder.fit_transform(steg_billing['counter_type'])

# %%
#Supprimer la fonction « counter_statue » de la trame de données
steg_billing.drop(columns=['counter_statue'])
# Out:
#                  client_id invoice_date  tarif_type  counter_number  \
# 0           train_Client_0   2014-03-24        11.0       1335667.0
# 1           train_Client_0   2013-03-29        11.0       1335667.0
# 2           train_Client_0   2015-03-23        11.0       1335667.0
# 3           train_Client_0   2015-07-13        11.0       1335667.0
# 4           train_Client_0   2016-11-17        11.0       1335667.0
# ...                    ...          ...         ...             ...
# 25765  train_Client_100713   2007-05-29        11.0       1077941.0
# 25766  train_Client_100713   2016-11-05        40.0        146251.0
# 25767  train_Client_100713   2007-05-29        40.0        146251.0
# 25768  train_Client_100713   2008-09-24        11.0       1077941.0
# 25769  train_Client_100713   2008-09-24         NaN             NaN
#
#        counter_code  reading_remarque  counter_coefficient  \
# 0             203.0               8.0                  1.0
# ...
